# %% [markdown]
# # Problem_Statement_and_Data_Preparation

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# At FootfallCam, we provide rich footfall data for retail stores as well as advanced analytics and insights to help business
# decision making. Our 3D sensor uses computer vision and complex AI algorithm to track footfall accurately. One of our
# key features is staff identification <br>
#
# A person is identified as a staff if s/he is wearing a staff name tag, i.e: <br>
# * person + tag = staff <br>
#
# As an AI Engineer, you have a few hundred of video samples from our 3D sensor. Here, you are given 1 sample
# (“sample.mp4”) which is the view from our 3D sensor. Within the clip, there is a person wearing the tag and walking
# along thcorridor, all other people are not wearing the tag <br>
#
# **Note:** There is only one staff in the video.g:

# %% [markdown]
# ## Objective

# %% [markdown]
# 1. Identify which frames in the clip have the staff present
# 2. Locate the staff xy coordinates when present in the clip

# %% [markdown]
# ## Data Collection: Extracting frames from sample video

# %% [markdown]
# Decided to extract 8 frames per second as I would like to have more samples of the tag (the sample video fps is 25 frames per second)

# %%
import cv2
import os

# Load the video
video_path = r"C:\Users\ruyit\Desktop\Play (Python)\Object detection (employee with tag)\sample.mp4"  # replace with your video path
output_folder = r"C:\Users\ruyit\Pictures\output4"     # output folder for frames
interval = 0.125                            # interval in seconds for frame extraction

# Create output directory if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Capture the video
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS)         # frames per second
frame_interval = int(fps * interval)    # interval in frames

frame_count = 0
saved_frame_count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Save frames at defined intervals
    if frame_count % frame_interval == 0:
        frame_name = f"{output_folder}/frame.c_{saved_frame_count}.png"
        cv2.imwrite(frame_name, frame)
        print(f"Saved {frame_name}")
        saved_frame_count += 1

    frame_count += 1

cap.release()
cv2.destroyAllWindows()
# Out:
# Saved C:\Users\ruyit\Pictures\output4/frame.c_0.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_1.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_2.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_3.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_4.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_5.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_6.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_7.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_8.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_9.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_10.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_11.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_12.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_13.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_14.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_15.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_16.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_17.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_18.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_19.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_20.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_21.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_22.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_23.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_24.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_25.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_26.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_27.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_28.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_29.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_30.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_31.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_32.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_33.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_34.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_35.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_36.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_37.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_38.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_39.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_40.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_41.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_42.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_43.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_44.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_45.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_46.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_47.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_48.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_49.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_50.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_51.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_52.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_53.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_54.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_55.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_56.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_57.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_58.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_59.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_60.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_61.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_62.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_63.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_64.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_65.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_66.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_67.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_68.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_69.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_70.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_71.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_72.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_73.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_74.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_75.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_76.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_77.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_78.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_79.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_80.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_81.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_82.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_83.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_84.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_85.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_86.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_87.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_88.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_89.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_90.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_91.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_92.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_93.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_94.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_95.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_96.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_97.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_98.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_99.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_100.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_101.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_102.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_103.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_104.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_105.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_106.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_107.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_108.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_109.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_110.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_111.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_112.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_113.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_114.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_115.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_116.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_117.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_118.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_119.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_120.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_121.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_122.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_123.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_124.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_125.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_126.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_127.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_128.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_129.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_130.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_131.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_132.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_133.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_134.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_135.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_136.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_137.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_138.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_139.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_140.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_141.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_142.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_143.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_144.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_145.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_146.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_147.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_148.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_149.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_150.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_151.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_152.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_153.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_154.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_155.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_156.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_157.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_158.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_159.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_160.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_161.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_162.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_163.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_164.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_165.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_166.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_167.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_168.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_169.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_170.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_171.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_172.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_173.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_174.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_175.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_176.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_177.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_178.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_179.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_180.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_181.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_182.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_183.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_184.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_185.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_186.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_187.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_188.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_189.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_190.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_191.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_192.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_193.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_194.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_195.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_196.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_197.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_198.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_199.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_200.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_201.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_202.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_203.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_204.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_205.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_206.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_207.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_208.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_209.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_210.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_211.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_212.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_213.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_214.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_215.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_216.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_217.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_218.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_219.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_220.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_221.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_222.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_223.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_224.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_225.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_226.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_227.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_228.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_229.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_230.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_231.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_232.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_233.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_234.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_235.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_236.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_237.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_238.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_239.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_240.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_241.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_242.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_243.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_244.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_245.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_246.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_247.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_248.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_249.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_250.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_251.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_252.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_253.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_254.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_255.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_256.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_257.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_258.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_259.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_260.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_261.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_262.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_263.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_264.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_265.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_266.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_267.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_268.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_269.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_270.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_271.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_272.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_273.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_274.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_275.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_276.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_277.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_278.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_279.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_280.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_281.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_282.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_283.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_284.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_285.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_286.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_287.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_288.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_289.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_290.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_291.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_292.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_293.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_294.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_295.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_296.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_297.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_298.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_299.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_300.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_301.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_302.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_303.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_304.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_305.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_306.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_307.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_308.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_309.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_310.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_311.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_312.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_313.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_314.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_315.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_316.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_317.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_318.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_319.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_320.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_321.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_322.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_323.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_324.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_325.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_326.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_327.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_328.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_329.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_330.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_331.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_332.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_333.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_334.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_335.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_336.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_337.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_338.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_339.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_340.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_341.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_342.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_343.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_344.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_345.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_346.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_347.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_348.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_349.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_350.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_351.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_352.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_353.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_354.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_355.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_356.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_357.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_358.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_359.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_360.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_361.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_362.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_363.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_364.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_365.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_366.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_367.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_368.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_369.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_370.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_371.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_372.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_373.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_374.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_375.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_376.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_377.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_378.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_379.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_380.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_381.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_382.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_383.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_384.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_385.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_386.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_387.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_388.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_389.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_390.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_391.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_392.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_393.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_394.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_395.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_396.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_397.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_398.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_399.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_400.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_401.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_402.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_403.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_404.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_405.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_406.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_407.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_408.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_409.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_410.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_411.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_412.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_413.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_414.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_415.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_416.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_417.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_418.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_419.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_420.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_421.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_422.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_423.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_424.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_425.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_426.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_427.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_428.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_429.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_430.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_431.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_432.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_433.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_434.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_435.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_436.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_437.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_438.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_439.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_440.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_441.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_442.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_443.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_444.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_445.png
# Saved C:\Users\ruyit\Pictures\output4/frame.c_446.png

# %%
print(f"fps = {fps}")                                              # Expected to print the FPS value, e.g., 25
print(f"cap.get(cv2.CAP_PROP_FPS) = {cap.get(cv2.CAP_PROP_FPS)}")  # Might print 0.0 if there's an issue reading FPS
print(f"cv2.CAP_PROP_FPS = {cv2.CAP_PROP_FPS}")                    # Will print 5, as this is a fixed constant
# Out:
# fps = 25.0
# cap.get(cv2.CAP_PROP_FPS) = 0.0
# cv2.CAP_PROP_FPS = 5

# %% [markdown]
# ## Use LabelImg to annotate / draw bounding box
# **Note:** <br>
# Cannot use labelImg in Jupyter Notebook. Need to use terminal/PowerShell <br>
# Terminal is opened (press Windows+R, and then type cmd)<br>
# Need to install Python [(Python Link)](https://www.python.org/downloads/release/python-3913/) and Visual C++ Build Tools [(VCBT Link)](https://visualstudio.microsoft.com/visual-cpp-build-tools/)<br>
#
# Ran the following line in terminal in order for LabelImg to work
# ```
# python -m venv labelimg_env      # Create a Virtual Environment
# labelimg_env\Scripts\activate    # Activate Environment
# labelImg                         # Run labelImg
# ```
# \* Need to use earlier versions of python so that it's compatible with LabelImg, so I used Python 3.9.13 <br>
# \* Run these if not installed yet:
# ```
# pip install pyqt5==5.15.2
# pip install labelImg
# ```

# %% [markdown]
# Steps taken:
# * Discard images which do not have person with tag visible
# * Label the staff with two bounding box, "person" and "tag" respectively
